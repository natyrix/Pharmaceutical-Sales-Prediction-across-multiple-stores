# %%
import numpy as np
import pandas as pd
import sys, os
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from read_write_util import ReadWriteUtil

# %%
reader = ReadWriteUtil()
df_store = reader.dvc_get_data('../data/store.csv', 'v1')
df_store
# Out:
# 2022-09-07 05:00:05,343:logger:../data/store.csv with version v1 Loaded
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# ...

# %%
df_s = df_store[:10]
df_s
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
# 5      6         a          a                310.0                       12.0
# 6      7         a          c              24000.0                        4.0
# 7      8         a          a               7520.0                       10.0
# 8      9         a          c               2030.0                        8.0
# 9     10         a          a               3160.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
reader.to_csv(df_s, "../data/store.csv")
# Out:
# 2022-09-07 04:52:59,122:logger:Saved to path ../data/store.csv

# %%
reader = ReadWriteUtil()
df_store = reader.dvc_get_data('../data/store.csv', 'v2store')
df_store
# Out:
# 2022-09-07 05:18:40,068:logger:../data/store.csv with version v2store Loaded
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# ...
